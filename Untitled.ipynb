# %%
import get_info as gi
import librosa
import matplotlib.pyplot as plt

# %%
filepath = '30_times.wav'
gi.basic_info(filepath)
gi.specshow_graph(filepath)

# %%
y, sr = librosa.load('30_times.wav', sr=20000)
y_harm, y_perc = librosa.effects.hpss(y)
plt.figure(figsize=(14, 5))
librosa.display.waveplot(y_harm, sr=sr, alpha=0.25)
librosa.display.waveplot(y_perc, sr=sr, color='r', alpha=0.5)
plt.title('Harmonic + Percussive')
plt.tight_layout()
plt.show()

tempo, beat_frames = librosa.beat.beat_track(y=y, sr=sr, hop_length=500)
beat_frames
# Out:
# /Users/Dodanto/anaconda3/lib/python3.7/site-packages/librosa/filters.py:221: UserWarning: Empty filters detected in mel frequency basis. Some channels will produce empty responses. Try increasing your sampling rate (and fmax) or reducing n_mels.
#   warnings.warn('Empty filters detected in mel frequency basis. '
# /Users/Dodanto/anaconda3/lib/python3.7/site-packages/librosa/beat.py:309: DeprecationWarning: np.asscalar(a) is deprecated since NumPy v1.16, use a.item() instead
#   hop_length=hop_length))
# array([  3,  29,  57,  85, 115, 144, 174, 206, 235, 263, 286, 308, 328,
#        352, 376, 400, 427, 453, 478, 503, 530, 558, 585, 612, 639, 664])

# %%
y, sr = librosa.load('30_times.wav', sr=20000)
y_mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=40, hop_length=500)
print(y_mfcc.shape)
print(y.shape)
# Out:
# (40, 741)
# (370417,)

# %%
plt.figure(figsize=(10, 4))
librosa.display.specshow(y_mfcc, x_axis='time')
plt.colorbar()
plt.title('MFCC')
plt.tight_layout()
plt.show()

# %%
y_mfcc
# Out:
# array([[-4.82621094e+02, -3.77481415e+02, -3.34807190e+02, ...,
#         -3.85593597e+02, -3.92775848e+02, -4.10241119e+02],
#        [ 6.96509247e+01,  1.09179108e+02,  1.12628052e+02, ...,
#          1.20213501e+02,  1.08649643e+02,  1.04779373e+02],
#        [-3.28748465e+00, -6.09599686e+00, -1.29542732e+00, ...,
#         -1.90214729e+00, -1.40583105e+01, -1.29871655e+01],
#        ...,
#        [-2.52232265e+00, -1.93186712e+00,  2.57846284e+00, ...,
#         -1.46497452e+00,  1.55118036e+00, -6.01557398e+00],
#        [-3.64909983e+00, -5.25766087e+00, -2.88439989e+00, ...,
#          2.73056507e+00,  4.68484020e+00,  2.94519246e-01],
#        [-1.31241798e+00, -6.82728148e+00, -6.38176203e+00, ...,
#          4.23417091e+00, -4.33873534e-01, -8.65296602e-01]], dtype=float32)

# %%
gi.lighten(y_mfcc)
# Out:
# array([[-4.8262109e+02, -3.7748141e+02, -3.3480719e+02, ...,
#         -3.8559360e+02, -3.9277585e+02, -4.1024112e+02],
#        [ 6.9650917e+01,  1.0917911e+02,  1.1262805e+02, ...,
#          1.2021350e+02,  1.0864964e+02,  1.0477937e+02],
#        [-3.2874801e+00, -6.0960002e+00, -1.2954299e+00, ...,
#         -1.9021500e+00, -1.4058310e+01, -1.2987160e+01],
#        ...,
#        [-2.5223200e+00, -1.9318700e+00,  2.5784600e+00, ...,
#         -1.4649700e+00,  1.5511800e+00, -6.0155702e+00],
#        [-3.6491001e+00, -5.2576599e+00, -2.8843999e+00, ...,
#          2.7305601e+00,  4.6848402e+00,  2.9451999e-01],
#        [-1.3124200e+00, -6.8272800e+00, -6.3817601e+00, ...,
#          4.2341700e+00, -4.3386999e-01, -8.6530000e-01]], dtype=float32)

# %%
y, sr = librosa.load('30_times.wav', sr=20000)
y_mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=40, hop_length=500)
_, beat_frames = librosa.beat.beat_track(y=y, sr=sr, hop_length=500)

for frame_number in beat_frames:
    print("#",frame_number)
    print(gi.lighten(y_mfcc.T[frame_number-1:frame_number+4].shape))
# Out:
# # 3
# (5, 40)
# # 29
# (5, 40)
# # 57
# (5, 40)
# # 85
# (5, 40)
# # 115
# (5, 40)
# # 144
# (5, 40)
# # 174
# (5, 40)
# # 206
# (5, 40)
# # 235
# (5, 40)
# # 263
# (5, 40)
# # 286
# (5, 40)
# # 308
# (5, 40)
# # 328
# (5, 40)
# # 352
# (5, 40)
# # 376
# (5, 40)
# # 400
# (5, 40)
# # 427
# (5, 40)
# # 453
# (5, 40)
# # 478
# (5, 40)
# # 503
# (5, 40)
# # 530
# (5, 40)
# # 558
# (5, 40)
# # 585
# (5, 40)
# # 612
# (5, 40)
# # 639
# (5, 40)
# # 664
# (5, 40)
# /Users/Dodanto/anaconda3/lib/python3.7/site-packages/librosa/filters.py:221: UserWarning: Empty filters detected in mel frequency basis. Some channels will produce empty responses. Try increasing your sampling rate (and fmax) or reducing n_mels.
#   warnings.warn('Empty filters detected in mel frequency basis. '
# /Users/Dodanto/anaconda3/lib/python3.7/site-packages/librosa/beat.py:309: DeprecationWarning: np.asscalar(a) is deprecated since NumPy v1.16, use a.item() instead
#   hop_length=hop_length))
