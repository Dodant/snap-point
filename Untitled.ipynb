# %%
import get_info as gi

filepath = '30_times.wav'
gi.basic_info(filepath)
gi.specshow_graph(filepath)
# Out:
# /Users/Dodanto/anaconda3/lib/python3.7/site-packages/librosa/filters.py:221: UserWarning: Empty filters detected in mel frequency basis. Some channels will produce empty responses. Try increasing your sampling rate (and fmax) or reducing n_mels.
#   warnings.warn('Empty filters detected in mel frequency basis. '
# /Users/Dodanto/anaconda3/lib/python3.7/site-packages/librosa/beat.py:309: DeprecationWarning: np.asscalar(a) is deprecated since NumPy v1.16, use a.item() instead
#   hop_length=hop_length))
# File Name : 30_times.wav
# File Duration : 18.52085
# Sampling Rate : 20000
# # of Samples : 370417
# Beat Times : 27
# [ 0.0768  0.7168  1.3056  1.9712  2.6368  3.2512  3.8656  4.5056  5.1456
#   5.76    6.4256  7.1424  7.68    8.192   8.8064  9.3952 10.0096 10.6752
#  11.3152 11.9552 12.5952 13.2608 13.952  14.6176 15.2832 15.9744 16.5888]

# %%
y, sr = librosa.load('30_times.wav', sr=20000)
y_harm, y_perc = librosa.effects.hpss(y)
plt.figure(figsize=(14, 5))
librosa.display.waveplot(y_harm, sr=sr, alpha=0.25)
librosa.display.waveplot(y_perc, sr=sr, color='r', alpha=0.5)
plt.title('Harmonic + Percussive')
plt.tight_layout()
plt.show()

# %%
y, sr = librosa.load('30_times.wav', sr=20000)
y_mfcc = librosa.feature.mfcc(y=y, sr=sr)
print(y_mfcc.shape)
print(y.shape)
# Out:
# (20, 724)
# (370417,)
