# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import librosa as lisa
import librosa.display
# %matplotlib inline

# %%
y_196, sr = lisa.load('./sound/snap_196.wav', sr=11025)
mfcc = librosa.feature.mfcc(y=y_196, sr=sr)
print(y_196.shape)
print(mfcc.shape)

# 3. Run the default beat tracker
tempo, beat_frames = librosa.beat.beat_track(y=y_196, sr=sr)
# 4. Convert the frame indices of beat events into timestamps
beat_times = librosa.frames_to_time(beat_frames, sr=sr)
print(beat_times)

plt.plot(y_196.flatten())
mfcc_delta = librosa.feature.delta(mfcc)
mfcc_delta.shape
# plt.plot(mfcc_delta)

# lisa.display.specshow(mfcc, x_axis='time')
# plt.colorbar()
# plt.title('MFCC')
# plt.tight_layout()
# plt.show()
# Out:
# (31752,)
# (20, 63)
# [0.13931973]
# /Users/Dodanto/anaconda3/lib/python3.7/site-packages/librosa/beat.py:309: DeprecationWarning: np.asscalar(a) is deprecated since NumPy v1.16, use a.item() instead
#   hop_length=hop_length))
# (20, 63)

# %%
y_44, sr = lisa.load('./sound/snap_44.wav', sr=11025)
mfcc = librosa.feature.mfcc(y=y_44, sr=sr)
print(y_44.shape)
print(mfcc.shape)
plt.plot(y_44.flatten())

# 3. Run the default beat tracker
tempo, beat_frames = librosa.beat.beat_track(y=y_44, sr=sr)

# 4. Convert the frame indices of beat events into timestamps
beat_times = librosa.frames_to_time(beat_frames, sr=sr)
print(beat_times)

# lisa.display.specshow(mfcc, x_axis='time')
# plt.colorbar()
# plt.title('MFCC')
# plt.tight_layout()
# plt.show()
# Out:
# (20947,)
# (20, 41)
# [0.13931973]
# /Users/Dodanto/anaconda3/lib/python3.7/site-packages/librosa/beat.py:309: DeprecationWarning: np.asscalar(a) is deprecated since NumPy v1.16, use a.item() instead
#   hop_length=hop_length))
